# %% [markdown]
# <a href="https://colab.research.google.com/github/Udynathcodes/Python-For-AI-And-ML/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Indexing

# %%
list1 = "Pythonisfun"
output = len(list1)
#output = list1[-3:]
print(output)
# Out:
# 11

# %%
food1 = ["Bread", "Plantain", "Yam", "Eggs", "Rice"]
Jemima = food1[1]
jem = food1[3]
print(f"Pls give me a plate of {Jemima} and {jem}")
# Out:
# Pls give me a plate of Plantain and Eggs

# %%
list_car = ["Toyota", "camry", "Benz", "Venza", "lexus"]
mill = list_car[2]
print(f"Millicent wants to buy a {mill}")
# Out:
# Millicent wants to buy a Benz

# %% [markdown]
# Python variable
# paschal = variable,
# sneakcase car_name, jemimafood
# student_name
#
# 1food
# qnt4
# num1

# %%
mix = ["abc", 37, "True", 23.9]
print(mix[2])
# Out:
# True

# %%
mod_list = ["Jemima", "millicent", 12, 50.3]
mod_list[2] = "Gold"
mod_list[1:3] = ["pin", "red"]

#insert method
mod_list.insert(2, "blue")
print(mod_list)
# Out:
# ['Jemima', 'pin', 'blue', 'red', 50.3]

# %%
new_list = [1, 2, 3, 4, 5]
#new_list.insert(2, "Jemima")
#new_list.append("Millicent")
#new_list.extend(["pin", "red"])
#new_list.remove(1)
#new_list.pop()
#new_list.pop(2)
#del new_list
new_list.clear()
print(new_list)
# Out:
# []

# %%
new_list= [71, 32, 65, 38]

new_list.reverse()
print(new_list)
# Out:
# [38, 65, 32, 71]

# %%
list1 = [1, 2, 3, 4]
list2 = ["a", "b", "c"]
list3 = list1 + list2
print(list3)
# Out:
# [1, 2, 3, 4, 'a', 'b', 'c']

# %% [markdown]
# tuple in python
# store multiple items in a variable
# is collection datatpye which is oredere and unchange it (immutable)
# tuple()

# %%
#my_tup = ("apple", "bread", "Banana", "bread", 21, True, 23.4 )
##print(len(my_tup))
#print(type(my_tup))
#print(f"these are the items in my tuple: {my_tup}")
new_tup = tuple((2, 3, 4, 5, 6))
print(new_tup[2:4])
print(new_tup)
#print(type(new_tup))
# Out:
# (4, 5)
# (2, 3, 4, 5, 6)

# %%
x = ("Apple", "Banana", "Cherry")
y = list(x)
y[1] = "kiwi"
x = tuple(y)
print(x)
# Out:
# ('Apple', 'kiwi', 'Cherry')

# %%
millicent = (2, 4, 5, 76)
jemima = list(millicent)
jemima[3] = "Gold"
millicent = tuple(jemima)
print(millicent)
# Out:
# (2, 4, 5, 'Gold')
