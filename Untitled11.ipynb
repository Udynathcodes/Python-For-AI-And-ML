# %% [markdown]
# <a href="https://colab.research.google.com/github/Udynathcodes/Python-For-AI-And-ML/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# {}
# unordered, unindexed

# %%
new_set = {"Millicent", "Jemima", "Gold", "Millicent"}
print(new_set)
print(type(new_set))
# Out:
# {'Jemima', 'Gold', 'Millicent'}
# <class 'set'>

# %%
test = {"apple", "banana", "cherry",True, 21, 43, 1}
test2 = {12, 34, 6, False, 32, "Jemima", 0}
test3 = [1, 45, 65, "pawpaw"]
test2.update(test3)
test2.add("Millicent")
test2.remove("Mango")
print(test2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4154/3272608498.py in <cell line: 0>()
#       4 test2.update(test3)
#       5 test2.add("Millicent")
# ----> 6 test2.remove("Mango", "Not found")
#       7 print(test2)
#
# TypeError: set.remove() takes exactly one argument (2 given)

# %%
cons = set(("John", "Mary", "Cheery"))
#for items in cons:
    #print(items)

print("Gold" in cons)

#print(cons)
# Out:
# False

# %%
Test_run = {"apple", "banana", "Cherry", "Jemima", "Gold"}
#Test_run.discard("Mango")
f = Test_run.pop()
print(f)
print(Test_run)
# Out:
# Cherry
# {'apple', 'Gold', 'Jemima', 'banana'}

# %% [markdown]
# Mathematical operations in set
# union()
# intersection()
# difference

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3, "a", "b"}
op = set1 & set2
print(op)
#set3 = set1.intersection(set2)

#print(set3)
#run1 = {"mill", "GOLD", 21}
#run2 = "victor", "Mango", 231
#addup = set1.union(set2, run1, run2)
#print(addup)
#set3 = set1 | set2 | run2
#print(set3)
# Out:
# {'b', 'a'}

# %%
jem = {"rice", "beans", "garri"}
fruits = {"pawpaw", "orange", "beans", "rice"}
#var = jem.difference(fruits)
var = jem - fruits
print(var)

#jem.intersection_update(fruits)
#print(jem)
# Out:
# {'garri'}

# %% [markdown]
# Dictionries in python
# {}
# Name: Millicent
# age: 15
# Nationality:Nigerian
# gender: female
# marital Status: married
#
# ordered, changeable
# no duplicates

# %%
new_dict = {"Name": "Millicent",
            "age": 15,
            "Nationality": "Nigerian",
            "gender": "female",
            "marital Status": "married",
            "Occupation": "Student",
            "Year of birth": 1995,
            "Country": "Nigerian"
            }
print(len(new_dict))
#print(new_dict['Name'])
#print(new_dict['Occupation'])
#print(type(new_dict))
# Out:
# 8

# %%
cons = dict(name = "Millicent", age = 15, Nationality = "Nigerian")
print(cons)
# Out:
# {'name': 'Millicent', 'age': 15, 'Nationality': 'Nigerian'}
