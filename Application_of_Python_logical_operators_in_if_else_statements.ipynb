# %% [markdown]
# <a href="https://colab.research.google.com/github/Udynathcodes/Python-For-AI-And-ML/blob/main/Application_of_Python_logical_operators_in_if_else_statements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# and = strict must true to both
# or = not check one condition
# Not returns false in what we have.

# %%
jem_age = 250
milli_age = 30
gold_age = 40

if jem_age < milli_age and gold_age > milli_age:
    print("Both condition are True")
else:
    print("Both condition are not True")
# Out:
# Both condition are not True

# %%
stud_grades1 = 80
stud_grades2 = 59
stud_grades3 = 7

if stud_grades1 > stud_grades3 or stud_grades2 > stud_grades1:
    print("One condition is True")
else:
    print("Both condition are not True")
# Out:
# One condition is True

# %%
a = 34
b = 59
if not a > b:
    print("A  is not greater than B")
else:
    print("A is greater than B")
# Out:
# A  is not greater than B

# %%
User_name = "Jemima"
password = "#Jemima124"
is_verified = False

if User_name and password and is_verified:
    print("Login sucsessfully")
    print("You can proced to the registration")
else:
    print("Login failed")
# Out:
# Login failed

# %% [markdown]
# Nested if statement in python

# %%
milli_age = 50

if milli_age > 18:
    print("You are an adult")
    if milli_age > 25:
        print("You are up to marrigeble age")
    else:
        print("You are not up to marrigeble age")
else:
    print("You are not an adult you still need time to grow")
# Out:
# You are not an adult you still need time to grow

# %%
grades = 50
attendace = 50
is_assignmet = False
summitted = True

if grades >= 70:
    if attendace >= 50:
        if is_assignmet:
            if summitted:
                print("Yod are a good student, you passed with distinction")
            else:
                print("You have pass but you did not do your assignment")
        else:
            print("You did not do your assignent")
    else:
        print("Pass , but your attendance is poor")
else:
    print("You failed, you have carried over this course")
# Out:
# You failed, you have carried over this course
