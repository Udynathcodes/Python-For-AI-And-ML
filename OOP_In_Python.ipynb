# %% [markdown]
# <a href="https://colab.research.google.com/github/Udynathcodes/Python-For-AI-And-ML/blob/main/OOP_In_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# OOp - Object Oriented programming in pyhton
# Helps keep your code DRY(Don't repeat Yourself)
#
# Class is object constructor or a bluprintfor creating objects
#
# class Car
# dundur
# __init__ method

# %%
class MyClass:
    x = 4

cls1 = MyClass()
CLS2 = MyClass()
print(cls1.x)
print(CLS2.x)
# Out:
# 4

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

p1 = Person("Jemima", 62)

print(p1.name)
print(p1.age)
# Out:
# Jemima
# 62

# %%
class Person:
    pass

p1 = Person()
p1.name = "Jemima"
p1.age = 62

print(p1.name)
print(p1.age)

# %%
class Person:
    def __init__(self, name, age=32):
        self.name = name
        self.age = age

    def myfunc(self):
        print("Hello my name is " + self.name)

p1 = Person("Jemima")
p2 = Person("Millicent", 23)

p1.myfunc()
p2.myfunc()


#print(p1.name, p1.age)
#print(p2.name, p2.age)
# Out:
# Hello my name is Jemima
# Hello my name is Millicent

# %%
class Car:
    def __init__(self, brand, model, year):
        self.brand = brand
        self.model = model
        self.year = year

    def display_info(self):
        print(f"Brand: {self.brand}, Model: {self.model}, Year: {self.year}")

car1 = Car("Toyota", "Camry", 2022)
car2 = Car("Honda", "Civic", 2021)

car1.display_info()
car2.display_info()
# Out:
# Brand: Toyota, Model: Camry, Year: 2022
# Brand: Honda, Model: Civic, Year: 2021
